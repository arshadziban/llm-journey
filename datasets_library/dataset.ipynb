# %%
from datasets import load_dataset

# %%
squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 squad_it_dataset = load_dataset("json", data_files="SQuAD_it-train.json", field="data")
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
#    2064     name=name,
#    2065     data_dir=data_dir,
#    2066     data_files=data_files,
#    2067     cache_dir=cache_dir,
#    2068     features=features,
#    2069     download_config=download_config,
#    2070     download_mode=download_mode,
#    2071     revision=revision,
#    2072     token=token,
#    2073     storage_options=storage_options,
#    2074     trust_remote_code=trust_remote_code,
#    2075     _require_default_config_name=name is None,
#    2076     **config_kwargs,
#    2077 )
#    2079 # Return iterable dataset in case of streaming
#    2080 if streaming:
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\load.py:1782, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1780     download_config = download_config.copy() if download_config else DownloadConfig()
#    1781     download_config.storage_options.update(storage_options)
# -> 1782 dataset_module = dataset_module_factory(
#    1783     path,
#    1784     revision=revision,
#    1785     download_config=download_config,
#    1786     download_mode=download_mode,
#    1787     data_dir=data_dir,
#    1788     data_files=data_files,
#    1789     cache_dir=cache_dir,
#    1790     trust_remote_code=trust_remote_code,
#    1791     _require_default_config_name=_require_default_config_name,
#    1792     _require_custom_configs=bool(config_kwargs),
#    1793 )
#    1794 # Get dataset builder class from the processing script
#    1795 builder_kwargs = dataset_module.builder_kwargs
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\load.py:1497, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1474 # We have several ways to get a dataset builder:
#    1475 #
#    1476 # - if path is the name of a packaged dataset module
#    (...)
#    1488
#    1489 # Try packaged
#    1490 if path in _PACKAGED_DATASETS_MODULES:
#    1491     return PackagedDatasetModuleFactory(
#    1492         path,
#    1493         data_dir=data_dir,
#    1494         data_files=data_files,
#    1495         download_config=download_config,
#    1496         download_mode=download_mode,
# -> 1497     ).get_module()
#    1498 # Try locally
#    1499 elif path.endswith(filename):
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\load.py:913, in PackagedDatasetModuleFactory.get_module(self)
#     907 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     908 patterns = (
#     909     sanitize_patterns(self.data_files)
#     910     if self.data_files is not None
#     911     else get_data_patterns(base_path, download_config=self.download_config)
#     912 )
# --> 913 data_files = DataFilesDict.from_patterns(
#     914     patterns,
#     915     download_config=self.download_config,
#     916     base_path=base_path,
#     917 )
#     919 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     921 builder_kwargs = {
#     922     "data_files": data_files,
#     923     "dataset_name": self.name,
#     924 }
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\data_files.py:690, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     685 out = cls()
#     686 for key, patterns_for_key in patterns.items():
#     687     out[key] = (
#     688         patterns_for_key
#     689         if isinstance(patterns_for_key, DataFilesList)
# --> 690         else DataFilesList.from_patterns(
#     691             patterns_for_key,
#     692             base_path=base_path,
#     693             allowed_extensions=allowed_extensions,
#     694             download_config=download_config,
#     695         )
#     696     )
#     697 return out
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\data_files.py:583, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     580 for pattern in patterns:
#     581     try:
#     582         data_files.extend(
# --> 583             resolve_pattern(
#     584                 pattern,
#     585                 base_path=base_path,
#     586                 allowed_extensions=allowed_extensions,
#     587                 download_config=download_config,
#     588             )
#     589         )
#     590     except FileNotFoundError:
#     591         if not has_magic(pattern):
#
# File d:\Skills\llm-journey\env\lib\site-packages\datasets\data_files.py:384, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     382     if allowed_extensions is not None:
#     383         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 384     raise FileNotFoundError(error_msg)
#     385 return out
#
# FileNotFoundError: Unable to find 'D:/Skills/llm-journey/datasets_library\SQuAD_it-train.json'
